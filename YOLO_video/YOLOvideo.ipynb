# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 15.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 82.2MB/s]

# %%
model.predict("https://raw.githubusercontent.com/youtube/api-samples/master/java/src/main/resources/sample-video.mp4",save=True,save_txt=True,classes= 0)
# Out:
# ...
# 100%|██████████| 314k/314k [00:00<00:00, 13.2MB/s]
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/265) /content/sample-video.mp4: 384x640 1 person, 97.6ms
# video 1/1 (2/265) /content/sample-video.mp4: 384x640 1 person, 7.6ms
# video 1/1 (3/265) /content/sample-video.mp4: 384x640 1 person, 8.0ms
# video 1/1 (4/265) /content/sample-video.mp4: 384x640 1 person, 8.2ms
# video 1/1 (5/265) /content/sample-video.mp4: 384x640 1 person, 8.0ms
# ...

# %%
model.predict("/content/1.mp4",save=True,save_txt=True,classes= 0)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/474) /content/1.mp4: 640x480 6 persons, 67.4ms
# video 1/1 (2/474) /content/1.mp4: 640x480 6 persons, 7.1ms
# video 1/1 (3/474) /content/1.mp4: 640x480 6 persons, 8.0ms
# video 1/1 (4/474) /content/1.mp4: 640x480 7 persons, 7.0ms
# video 1/1 (5/474) /content/1.mp4: 640x480 6 persons, 8.0ms
# video 1/1 (6/474) /content/1.mp4: 640x480 6 persons, 7.3ms
# video 1/1 (7/474) /content/1.mp4: 640x480 7 persons, 8.0ms
# ...

# %%
model.predict("/content/2.mp4",save=True,save_txt=True,classes= 0)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/359) /content/2.mp4: 640x384 3 persons, 456.4ms
# video 1/1 (2/359) /content/2.mp4: 640x384 2 persons, 6.3ms
# video 1/1 (3/359) /content/2.mp4: 640x384 3 persons, 8.3ms
# video 1/1 (4/359) /content/2.mp4: 640x384 3 persons, 6.8ms
# video 1/1 (5/359) /content/2.mp4: 640x384 3 persons, 9.0ms
# video 1/1 (6/359) /content/2.mp4: 640x384 2 persons, 6.3ms
# video 1/1 (7/359) /content/2.mp4: 640x384 2 persons, 7.8ms
# ...
